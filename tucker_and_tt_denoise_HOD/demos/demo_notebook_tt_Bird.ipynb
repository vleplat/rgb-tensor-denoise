# %% [markdown]
# ## 🧩 Image Reconstruction
#
# This task focuses on **image denoising and reconstruction** using local low-rank **tensor decomposition** (Tucker or Tensor Train) within segmented image regions.
#
# ---
#
# ### 🖼️ Problem Setup
#
# You are given a **color image** $ Y \in \mathbb{R}^{I \times J \times 3}$ that is degraded by **Gaussian noise** with:
# - Mean = 0
# - Standard deviation = $ \sigma $
#
# ---
#
# ### 🧱 Step-by-Step Instructions
#
# #### **(a) Superpixel Clustering / Segmentation**
#
# - Segment the noisy image $ Y $ using a superpixel clustering algorithm (e.g., SLIC).
# - This produces clusters (segments) of pixels with similar appearance.
#
# #### **(b) Patch Tensor Construction + Low-Rank Approximation**
#
# For **each segment**:
#
# 1. **Extract patches**:
#    - For each pixel in the segment, extract a centered patch of size $ d \times d \times 3 $.
#    - Stack all patches into a tensor:
#      $
#      X \in \mathbb{R}^{d \times d \times 3 \times K}
#      $
#      where $K $ is the number of pixels (patches) in the segment.
#
# 2. **Denoise using a low-rank tensor model**:
#    - Approximate $ X $ using a **Tucker** or **Tensor Train (TT)** decomposition:
#      $
#      \hat{X} \approx X
#      $
#    - Subject to a reconstruction error bound:
#      $
#      \| X - \hat{X} \|_F^2 \leq \epsilon^2 = 3\sigma^2 d^2 K
#      $
#    - Goal: minimize the **number of parameters** in $ \hat{X} $.
#
# 2. **Notes**:
#   - For TT: two methods can be used
#     - TT decomposition with fixed ranks
#     - TT decomposition with error bounded constraints -> it computes the best TT ranks so that the error of approximation is bounded (for each patch)
#   - For each method, we have the choice of the shape
#     - One may keep the orginal 4-th order format of $X$
#     - One can reshape it into a 6-th order tensor format, then compute the TT decomposition. The motivation is to take advantage of TT compression capabilities for high-order tensors, in other words to obtain higher compression
#   - Parameters to play with:
#     - the value of $\sigma$ - for real life noisy signals, we have to try different values
#     - the value of $d$ - this has an impact on the smoothing since higher value for $d$ leads to higher overlapping for the aggregation steps. (cell ""3. Extract patches per superpixel"")
#     - activate or not the 6-th order reshaping: set parameter "reshape_for_tt" to False or True (cell"" 4. Denoise each patch GROUP27"")
#     - n_segments for superpixel method (cell "2. Superpixel segmentation")
#
# ---
#
# #### **(c) Reconstruct the Image**
#
# 1. Place denoised patches back into their original image locations.
# 2. Average overlapping regions.
# 3. Compute reconstruction quality metrics:
#    - **PSNR** (Peak Signal-to-Noise Ratio)
#    - **SSIM** (Structural Similarity Index)
#
# ---
#
# ### 🎯 Goal
#
# Reconstruct a **high-quality, denoised image** by leveraging **local patch redundancy** through **low-rank tensor decompositions** on segments of the image.

# %%
from IPython.display import Image, display

# Display with controlled width/height
display(Image(filename="../Datasets/illustration_superpixel.png", width=500, height=300))

# %% [markdown]
# Figure 1: Illustration of centroid superpixel sampling
#
# ---

# %% [markdown]
# We can start now )

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('.'))))

import numpy as np
import matplotlib.pyplot as plt
from tucker_and_tt_denoise_HOD import (
    load_image, add_gaussian_noise,
    superpixel_segmentation, extract_clustered_patches,
    tucker_decompose_and_denoise, reconstruct_image_from_patches,
    compute_quality_metrics, decompose_and_denoise_patch,tt_num_parameters,
    tt_compression_ratio
)

# %% [markdown]
# A very simple test before on a small patch

# %%
# Single patch test (4D)
patch = np.random.rand(6, 6, 3, 20)  # (h, w, C)

# Test Tucker
X_hat, (G, U), reshape_for_tt = decompose_and_denoise_patch(patch, method='tucker', sigma=0.1, reshape_for_tt=False)
print(X_hat.shape)  # Should return (6, 6, 3, 20)
print(G.shape, len(U))
# Out:
# 18.20014854931651 bound 21.600000000000005
# Ranks [6, 6, 3, 16]
# (6, 6, 3, 20)
# (6, 6, 3, 16) 4

# %%
# Test TT adaptative without 6-order reshape
X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch, method='tt_adaptive', sigma=0.1, reshape_for_tt=False, target_order=6)
print(X_hat.shape, len(tt_tensor), reshape_for_tt)
# Out:
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 6]
# 0  | (R1,R2) (16, 6) |  #params 2084 | approx 0.02507  | approx.bound 0.03124
# 1  | (R1,R2) (16, 6) |  #params 2084 | approx 0.02507  | approx.bound 0.03124
# Perform the 2-th Tucker-2 decomposition
# Approximation Error 21.645438363956146 | Predefined Bound 22.680000000000007
# (6, 6, 3, 20) 4 False

# %%
# Test TT adaptative with 6-order reshape
X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch, method='tt_adaptive', sigma=0.1, reshape_for_tt=True, target_order=6)
print(X_hat.shape, len(tt_tensor), reshape_for_tt)
# Out:
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [23, 2]
# 0  | (R1,R2) (23, 2) |  #params 2143 | approx 0.02751  | approx.bound 0.03124
# 1  | (R1,R2) (23, 2) |  #params 2143 | approx 0.02751  | approx.bound 0.03124
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 4]
# 0  | (R1,R2) (16, 4) |  #params 1376 | approx -4.831e-16  | approx.bound 0.003839
# 1  | (R1,R2) (16, 4) |  #params 1376 | approx -1.61e-16  | approx.bound 0.003839
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 19.96997643055704 | Predefined Bound 22.680000000000007
# (6, 6, 3, 20) 6 True

# %% [markdown]
# Now, we can start playing with a true RGB image

# %%
# 1. Load image + add noise
# image = load_image("../Datasets/cat1.jpg")       # Replace with your  image
# image = load_image("../Datasets/baboon.bmp")     # Replace with your image
image = load_image("../Datasets/parrot_small.jpg") # Replace with your image
# image = load_image("Datasets/ara.jpeg")


mean, sigma = 0, 0.07
noisy = add_gaussian_noise(image, mean, sigma)

plt.imshow(image)
plt.show()

plt.imshow(noisy)
plt.show()

# %%
# 2. Superpixel segmentation
# segments = superpixel_segmentation(noisy, n_segments=100, compactness=20) # lower level seg for SR, 2000 for higher level
# segments = superpixel_segmentation(noisy, n_segments=10, compactness=30)
segments = superpixel_segmentation(noisy, n_segments=50, compactness=30)

# %%
from skimage.segmentation import mark_boundaries
# plt.figure(figsize=(5, 5))
plt.subplot(1, 2, 1)
plt.imshow(noisy)
plt.subplot(1, 2, 2)
plt.imshow(mark_boundaries(noisy, segments))
plt.show()

# %%
# 3. Extract patches per superpixel
d = 5
patch_size = d  # Adjust based on tiling artifact size
patches = extract_clustered_patches(noisy, segments, patch_size=patch_size)

# %%
len(patches), patches[0][1].shape
# Out:
# (41, (4, 4, 3, 909))

# %%
# 4. Denoise each patch GROUP (order-4 tensor or order-6) - TT
denoised_patches = []
denoised_patches_factors = []
total_params = 0
original_params = 0
# sigma = 0.01 # for SR

for segidx, patch_group in patches:
    # patch_group shape: (h, w, C, num_patches)
    print(f'--------------------------------------------------------------------')
    print(f'Decomposing for segment {segidx}')
    # X_hat, G, U = tucker_decompose_and_denoise(patch_group, sigma) # Tucker
    X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch_group, method='tt_adaptive', sigma = sigma, reshape_for_tt=True, target_order=10)
    denoised_patches.append((segidx, X_hat))
    denoised_patches_factors.append((segidx, tt_tensor))
    total_params = total_params + tt_num_parameters(tt_tensor)
    original_params = original_params + np.prod(patch_group.shape)
    print(f'--------------------------------------------------------------------')

ratio = total_params / original_params
print(f"TT uses {total_params} parameters, compression ratio = {ratio:.4f}")
# Out:
# --------------------------------------------------------------------
# Decomposing for segment 1
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 1]
# 0  | (R1,R2) (4, 1) |  #params 1270 | approx 0.05802  | approx.bound 0.05914
# 1  | (R1,R2) (4, 1) |  #params 1270 | approx 0.05802  | approx.bound 0.05914
# 2  | (R1,R2) (4, 1) |  #params 1270 | approx 0.05802  | approx.bound 0.05914
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [5, 1]
# 0  | (R1,R2) (5, 1) |  #params 242 | approx 0.0009236  | approx.bound 0.001183
# 1  | (R1,R2) (5, 1) |  #params 242 | approx 0.0009236  | approx.bound 0.001183
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 2]
# 0  | (R1,R2) (4, 2) |  #params 112 | approx 5.383e-05  | approx.bound 0.0002593
# 1  | (R1,R2) (4, 2) |  #params 112 | approx 5.383e-05  | approx.bound 0.0002593
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 223.7846178575869 | Predefined Bound 224.48664000000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 2
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [6, 1]
# 0  | (R1,R2) (5, 1) |  #params 6027 | approx 0.06325  | approx.bound 0.06478
# 1  | (R1,R2) (5, 1) |  #params 6027 | approx 0.06325  | approx.bound 0.06478
# 2  | (R1,R2) (5, 1) |  #params 6027 | approx 0.06325  | approx.bound 0.06478
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 1]
# 0  | (R1,R2) (4, 1) |  #params 94 | approx 0.000228  | approx.bound 0.001629
# 1  | (R1,R2) (4, 1) |  #params 94 | approx 0.000228  | approx.bound 0.001629
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 2]
# 0  | (R1,R2) (2, 2) |  #params 28 | approx 5.668e-06  | approx.bound 0.001401
# 1  | (R1,R2) (2, 2) |  #params 28 | approx 5.668e-06  | approx.bound 0.001401
# Approximation Error [559.93826145 559.93826145] | Predefined Bound 571.4654400000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 3
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 4673 | approx 0.02291  | approx.bound 0.02314
# 1  | (R1,R2) (7, 2) |  #params 4673 | approx 0.02291  | approx.bound 0.02314
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 3]
# 0  | (R1,R2) (7, 3) |  #params 327 | approx 0.0001288  | approx.bound 0.0002291
# 1  | (R1,R2) (7, 3) |  #params 327 | approx 0.0001288  | approx.bound 0.0002291
# 2  | (R1,R2) (7, 3) |  #params 327 | approx 0.0001288  | approx.bound 0.0002291
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 4]
# 0  | (R1,R2) (4, 4) |  #params 112 | approx 3.671e-05  | approx.bound 0.0001003
# 1  | (R1,R2) (4, 4) |  #params 112 | approx 3.671e-05  | approx.bound 0.0001003
# 2  | (R1,R2) (4, 4) |  #params 112 | approx 3.671e-05  | approx.bound 0.0001003
# Approximation Error [281.27098119 281.27097476 281.27097467] | Predefined Bound 282.02832000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 4
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 10096 | approx 0.009789  | approx.bound 0.00985
# 1  | (R1,R2) (12, 2) |  #params 10096 | approx 0.009789  | approx.bound 0.00985
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [34, 4]
# 0  | (R1,R2) (34, 4) |  #params 9944 | approx 5.65e-05  | approx.bound 6.215e-05
# 1  | (R1,R2) (34, 4) |  #params 9944 | approx 5.65e-05  | approx.bound 6.215e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [65, 8]
# 0  | (R1,R2) (65, 8) |  #params 12804 | approx 4.252e-06  | approx.bound 5.652e-06
# 1  | (R1,R2) (65, 8) |  #params 12804 | approx 4.252e-06  | approx.bound 5.652e-06
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [62, 16]
# 0  | (R1,R2) (62, 16) |  #params 12284 | approx 1.368e-06  | approx.bound 1.4e-06
# 1  | (R1,R2) (62, 16) |  #params 12284 | approx 1.368e-06  | approx.bound 1.4e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 288.4483563296708 | Predefined Bound 288.44928000000004
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 5
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [35, 1]
# 0  | (R1,R2) (18, 1) |  #params 22268 | approx 0.01882  | approx.bound 0.01885
# 1  | (R1,R2) (18, 1) |  #params 22268 | approx 0.01882  | approx.bound 0.01885
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 500 | approx 3.5e-16  | approx.bound 3.757e-05
# 1  | (R1,R2) (8, 2) |  #params 500 | approx 8.167e-16  | approx.bound 3.757e-05
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 298.9767615894307 | Predefined Bound 299.56248000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 6
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [9, 2]
# 0  | (R1,R2) (9, 2) |  #params 5791 | approx 0.01339  | approx.bound 0.0135
# 1  | (R1,R2) (9, 2) |  #params 5791 | approx 0.01339  | approx.bound 0.0135
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 4]
# 0  | (R1,R2) (24, 4) |  #params 5272 | approx 0.0001011  | approx.bound 0.0001072
# 1  | (R1,R2) (24, 4) |  #params 5272 | approx 0.0001011  | approx.bound 0.0001072
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [53, 8]
# 0  | (R1,R2) (53, 8) |  #params 7272 | approx 5.957e-06  | approx.bound 6.116e-06
# 1  | (R1,R2) (53, 8) |  #params 7272 | approx 5.957e-06  | approx.bound 6.116e-06
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [32, 16]
# 0  | (R1,R2) (32, 16) |  #params 4672 | approx -2.507e-16  | approx.bound 1.594e-07
# 1  | (R1,R2) (32, 16) |  #params 4672 | approx -3.761e-16  | approx.bound 1.594e-07
# Approximation Error [198.55352727 198.55352727] | Predefined Bound 198.55584000000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 7
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1319 | approx 0.005331  | approx.bound 0.005687
# 1  | (R1,R2) (1, 1) |  #params 1319 | approx 0.005331  | approx.bound 0.005687
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 221 | approx 0.0002897  | approx.bound 0.0003582
# 1  | (R1,R2) (1, 1) |  #params 221 | approx 0.0002897  | approx.bound 0.0003582
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 41 | approx 6.325e-05  | approx.bound 6.854e-05
# 1  | (R1,R2) (1, 1) |  #params 41 | approx 6.325e-05  | approx.bound 6.854e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 2]
# 0  | (R1,R2) (1, 2) |  #params 20 | approx 3.368e-06  | approx.bound 5.296e-06
# 1  | (R1,R2) (1, 2) |  #params 20 | approx 3.368e-06  | approx.bound 5.296e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 279.9582501032346 | Predefined Bound 280.05264000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 8
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 1]
# 0  | (R1,R2) (7, 1) |  #params 4419 | approx 0.006174  | approx.bound 0.006466
# 1  | (R1,R2) (7, 1) |  #params 4419 | approx 0.006174  | approx.bound 0.006466
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [10, 1]
# 0  | (R1,R2) (10, 1) |  #params 1172 | approx 0.0002765  | approx.bound 0.0002933
# 1  | (R1,R2) (10, 1) |  #params 1172 | approx 0.0002765  | approx.bound 0.0002933
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [13, 2]
# 0  | (R1,R2) (13, 2) |  #params 810 | approx 1.358e-05  | approx.bound 1.688e-05
# 1  | (R1,R2) (13, 2) |  #params 810 | approx 1.358e-05  | approx.bound 1.688e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [10, 3]
# 0  | (R1,R2) (10, 3) |  #params 392 | approx 2.084e-06  | approx.bound 3.305e-06
# 1  | (R1,R2) (10, 3) |  #params 392 | approx 2.084e-06  | approx.bound 3.305e-06
# 2  | (R1,R2) (10, 3) |  #params 392 | approx 2.084e-06  | approx.bound 3.305e-06
# 3  | (R1,R2) (10, 3) |  #params 392 | approx 2.084e-06  | approx.bound 3.305e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 325.9260582425559 | Predefined Bound 325.9872000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 9
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 2]
# 0  | (R1,R2) (24, 2) |  #params 13276 | approx 0.01664  | approx.bound 0.01683
# 1  | (R1,R2) (24, 2) |  #params 13276 | approx 0.01664  | approx.bound 0.01683
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [51, 4]
# 0  | (R1,R2) (51, 4) |  #params 10216 | approx 0.0001829  | approx.bound 0.0001951
# 1  | (R1,R2) (51, 4) |  #params 10216 | approx 0.0001829  | approx.bound 0.0001951
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [53, 8]
# 0  | (R1,R2) (53, 8) |  #params 8862 | approx 1.196e-05  | approx.bound 1.213e-05
# 1  | (R1,R2) (53, 8) |  #params 8862 | approx 1.196e-05  | approx.bound 1.213e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [32, 16]
# 0  | (R1,R2) (32, 16) |  #params 4672 | approx 9.326e-16  | approx.bound 1.775e-07
# 1  | (R1,R2) (32, 16) |  #params 4672 | approx 7.461e-16  | approx.bound 1.775e-07
# Approximation Error [333.88645774 333.88645774] | Predefined Bound 333.88992
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 10
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 1]
# 0  | (R1,R2) (7, 1) |  #params 2865 | approx 0.1239  | approx.bound 0.125
# 1  | (R1,R2) (7, 1) |  #params 2865 | approx 0.1239  | approx.bound 0.125
# 2  | (R1,R2) (7, 1) |  #params 2865 | approx 0.1239  | approx.bound 0.125
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [6, 2]
# 0  | (R1,R2) (6, 2) |  #params 358 | approx 0.0009254  | approx.bound 0.001224
# 1  | (R1,R2) (6, 2) |  #params 358 | approx 0.0009254  | approx.bound 0.001224
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [6, 3]
# 0  | (R1,R2) (5, 3) |  #params 132 | approx 0.0002965  | approx.bound 0.0002984
# 1  | (R1,R2) (5, 3) |  #params 132 | approx 0.0002965  | approx.bound 0.0002984
# Approximation Error [356.85252817 356.85252816] | Predefined Bound 356.85720000000003
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 11
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1429 | approx 0.001935  | approx.bound 0.005464
# 1  | (R1,R2) (1, 1) |  #params 1429 | approx 0.001935  | approx.bound 0.005464
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 4.43e-08  | approx.bound 0.003536
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 4.43e-08  | approx.bound 0.003536
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 122.71928599161765 | Predefined Bound 346.48488000000003
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 12
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [10, 2]
# 0  | (R1,R2) (10, 2) |  #params 13674 | approx 0.05408  | approx.bound 0.05781
# 1  | (R1,R2) (10, 2) |  #params 13674 | approx 0.05408  | approx.bound 0.05781
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 3]
# 0  | (R1,R2) (8, 3) |  #params 348 | approx 0.0003656  | approx.bound 0.003935
# 1  | (R1,R2) (8, 3) |  #params 348 | approx 0.0003656  | approx.bound 0.003935
# 2  | (R1,R2) (8, 3) |  #params 348 | approx 0.0003656  | approx.bound 0.003935
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 314.53626376335615 | Predefined Bound 325.74024000000003
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 13
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [11, 2]
# 0  | (R1,R2) (11, 2) |  #params 17153 | approx 0.03915  | approx.bound 0.03978
# 1  | (R1,R2) (11, 2) |  #params 17153 | approx 0.03915  | approx.bound 0.03978
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [9, 4]
# 0  | (R1,R2) (9, 4) |  #params 457 | approx 6.838e-05  | approx.bound 0.0006513
# 1  | (R1,R2) (9, 4) |  #params 457 | approx 6.838e-05  | approx.bound 0.0006513
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 370.37789982570393 | Predefined Bound 373.15656000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 14
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [18, 2]
# 0  | (R1,R2) (18, 2) |  #params 13810 | approx 0.01672  | approx.bound 0.01725
# 1  | (R1,R2) (18, 2) |  #params 13810 | approx 0.01672  | approx.bound 0.01725
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 4]
# 0  | (R1,R2) (14, 4) |  #params 1220 | approx 0.0004285  | approx.bound 0.0005399
# 1  | (R1,R2) (14, 4) |  #params 1220 | approx 0.0004285  | approx.bound 0.0005399
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 8]
# 0  | (R1,R2) (7, 8) |  #params 372 | approx 9.653e-05  | approx.bound 0.0001115
# 1  | (R1,R2) (7, 8) |  #params 372 | approx 9.653e-05  | approx.bound 0.0001115
# Approximation Error [331.13824901 331.13824901] | Predefined Bound 331.42032000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 15
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [3, 1]
# 0  | (R1,R2) (3, 1) |  #params 4487 | approx 0.04664  | approx.bound 0.04776
# 1  | (R1,R2) (3, 1) |  #params 4487 | approx 0.04664  | approx.bound 0.04776
# 2  | (R1,R2) (3, 1) |  #params 4487 | approx 0.04664  | approx.bound 0.04776
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 28 | approx 0.0001247  | approx.bound 0.001182
# 1  | (R1,R2) (2, 1) |  #params 28 | approx 0.0001247  | approx.bound 0.001182
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 355.6080735956584 | Predefined Bound 363.27816000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 16
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [35, 2]
# 0  | (R1,R2) (35, 2) |  #params 24329 | approx 0.01152  | approx.bound 0.01173
# 1  | (R1,R2) (35, 2) |  #params 24329 | approx 0.01152  | approx.bound 0.01173
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [28, 4]
# 0  | (R1,R2) (28, 4) |  #params 8220 | approx 0.0002063  | approx.bound 0.0002119
# 1  | (R1,R2) (28, 4) |  #params 8220 | approx 0.0002063  | approx.bound 0.0002119
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 8]
# 0  | (R1,R2) (15, 8) |  #params 1564 | approx 1.887e-06  | approx.bound 5.61e-06
# 1  | (R1,R2) (15, 8) |  #params 1564 | approx 1.887e-06  | approx.bound 5.61e-06
# Approximation Error [620.41574722 620.41574722] | Predefined Bound 620.6104800000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 17
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [33, 1]
# 0  | (R1,R2) (17, 1) |  #params 24193 | approx 0.0166  | approx.bound 0.01662
# 1  | (R1,R2) (17, 1) |  #params 24193 | approx 0.0166  | approx.bound 0.01662
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 476 | approx 0  | approx.bound 1.885e-05
# 1  | (R1,R2) (8, 2) |  #params 476 | approx -3.559e-16  | approx.bound 1.885e-05
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 345.11176581530526 | Predefined Bound 345.4970400000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 18
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 507 | approx 0.002959  | approx.bound 0.005597
# 1  | (R1,R2) (1, 1) |  #params 507 | approx 0.002959  | approx.bound 0.005597
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 17 | approx 1.848e-05  | approx.bound 0.002645
# 1  | (R1,R2) (1, 1) |  #params 17 | approx 1.848e-05  | approx.bound 0.002645
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 7 | approx 8.928e-07  | approx.bound 0.002627
# 1  | (R1,R2) (1, 1) |  #params 7 | approx 8.928e-07  | approx.bound 0.002627
# Approximation Error [170.71426931 170.71426931] | Predefined Bound 320.80104000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 19
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [17, 2]
# 0  | (R1,R2) (17, 2) |  #params 13859 | approx 0.01114  | approx.bound 0.01126
# 1  | (R1,R2) (17, 2) |  #params 13859 | approx 0.01114  | approx.bound 0.01126
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [50, 4]
# 0  | (R1,R2) (50, 4) |  #params 15366 | approx 7.151e-05  | approx.bound 0.0001193
# 1  | (R1,R2) (50, 4) |  #params 15366 | approx 7.151e-05  | approx.bound 0.0001193
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [82, 8]
# 0  | (R1,R2) (82, 8) |  #params 18760 | approx 4.285e-05  | approx.bound 4.78e-05
# 1  | (R1,R2) (82, 8) |  #params 18760 | approx 4.285e-05  | approx.bound 4.78e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [63, 16]
# 0  | (R1,R2) (63, 16) |  #params 14620 | approx 3.056e-06  | approx.bound 4.945e-06
# 1  | (R1,R2) (63, 16) |  #params 14620 | approx 3.056e-06  | approx.bound 4.945e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 185.68311234775138 | Predefined Bound 185.71392000000003
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 20
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [19, 2]
# 0  | (R1,R2) (19, 2) |  #params 13817 | approx 0.0811  | approx.bound 0.08271
# 1  | (R1,R2) (19, 2) |  #params 13817 | approx 0.0811  | approx.bound 0.08271
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [13, 4]
# 0  | (R1,R2) (13, 4) |  #params 1381 | approx 0.001547  | approx.bound 0.001744
# 1  | (R1,R2) (13, 4) |  #params 1381 | approx 0.001547  | approx.bound 0.001744
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [9, 7]
# 0  | (R1,R2) (9, 7) |  #params 533 | approx 0.0001588  | approx.bound 0.0001974
# 1  | (R1,R2) (9, 7) |  #params 533 | approx 0.0001588  | approx.bound 0.0001974
# 2  | (R1,R2) (9, 7) |  #params 533 | approx 0.0001588  | approx.bound 0.0001974
# Approximation Error [431.74791136 431.747898   431.74789795] | Predefined Bound 431.93304000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 21
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [11, 2]
# 0  | (R1,R2) (11, 2) |  #params 6945 | approx 0.1059  | approx.bound 0.1065
# 1  | (R1,R2) (11, 2) |  #params 6945 | approx 0.1059  | approx.bound 0.1065
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 4]
# 0  | (R1,R2) (15, 4) |  #params 1231 | approx 0.000676  | approx.bound 0.0007001
# 1  | (R1,R2) (15, 4) |  #params 1231 | approx 0.000676  | approx.bound 0.0007001
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 8]
# 0  | (R1,R2) (14, 8) |  #params 918 | approx 1.864e-05  | approx.bound 2.41e-05
# 1  | (R1,R2) (14, 8) |  #params 918 | approx 1.864e-05  | approx.bound 2.41e-05
# Approximation Error [360.79200849 360.79200849] | Predefined Bound 360.8085600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 22
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [21, 1]
# 0  | (R1,R2) (12, 1) |  #params 22022 | approx 0.01497  | approx.bound 0.01516
# 1  | (R1,R2) (12, 1) |  #params 22022 | approx 0.01497  | approx.bound 0.01516
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 356 | approx -7.513e-16  | approx.bound 0.0002003
# 1  | (R1,R2) (8, 2) |  #params 356 | approx -6.261e-16  | approx.bound 0.0002003
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 441.425060319536 | Predefined Bound 447.2445600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 23
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [5, 1]
# 0  | (R1,R2) (5, 1) |  #params 1647 | approx 0.006372  | approx.bound 0.0067
# 1  | (R1,R2) (5, 1) |  #params 1647 | approx 0.006372  | approx.bound 0.0067
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 1]
# 0  | (R1,R2) (7, 1) |  #params 331 | approx 0.0002556  | approx.bound 0.0003302
# 1  | (R1,R2) (7, 1) |  #params 331 | approx 0.0002556  | approx.bound 0.0003302
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 1]
# 0  | (R1,R2) (4, 1) |  #params 90 | approx 5.524e-05  | approx.bound 7.462e-05
# 1  | (R1,R2) (4, 1) |  #params 90 | approx 5.524e-05  | approx.bound 7.462e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 22 | approx 8.439e-06  | approx.bound 1.938e-05
# 1  | (R1,R2) (2, 1) |  #params 22 | approx 8.439e-06  | approx.bound 1.938e-05
# Approximation Error [270.22906047 270.22906047] | Predefined Bound 270.66816000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 24
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [10, 2]
# 0  | (R1,R2) (10, 2) |  #params 16014 | approx 0.046  | approx.bound 0.04961
# 1  | (R1,R2) (10, 2) |  #params 16014 | approx 0.046  | approx.bound 0.04961
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 3]
# 0  | (R1,R2) (7, 3) |  #params 306 | approx 0.001652  | approx.bound 0.003774
# 1  | (R1,R2) (7, 3) |  #params 306 | approx 0.001652  | approx.bound 0.003774
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 367.8729795478048 | Predefined Bound 383.5288800000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 25
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [20, 1]
# 0  | (R1,R2) (19, 1) |  #params 12181 | approx 0.01227  | approx.bound 0.0123
# 1  | (R1,R2) (19, 1) |  #params 12181 | approx 0.01227  | approx.bound 0.0123
# 2  | (R1,R2) (19, 1) |  #params 12181 | approx 0.01227  | approx.bound 0.0123
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [53, 2]
# 0  | (R1,R2) (53, 2) |  #params 13201 | approx 2.873e-05  | approx.bound 3.704e-05
# 1  | (R1,R2) (53, 2) |  #params 13201 | approx 2.873e-05  | approx.bound 3.704e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [61, 4]
# 0  | (R1,R2) (61, 4) |  #params 13619 | approx 7.141e-06  | approx.bound 8.316e-06
# 1  | (R1,R2) (61, 4) |  #params 13619 | approx 7.141e-06  | approx.bound 8.316e-06
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [32, 8]
# 0  | (R1,R2) (32, 8) |  #params 4992 | approx 1.176e-16  | approx.bound 1.175e-06
# 1  | (R1,R2) (32, 8) |  #params 4992 | approx 8.233e-16  | approx.bound 1.175e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 385.2212507680015 | Predefined Bound 385.2576
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 26
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [25, 2]
# 0  | (R1,R2) (25, 2) |  #params 31529 | approx 0.01772  | approx.bound 0.01816
# 1  | (R1,R2) (25, 2) |  #params 31529 | approx 0.01772  | approx.bound 0.01816
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [95, 4]
# 0  | (R1,R2) (95, 4) |  #params 34691 | approx 0.0004465  | approx.bound 0.0004533
# 1  | (R1,R2) (95, 4) |  #params 34691 | approx 0.0004465  | approx.bound 0.0004533
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [48, 8]
# 0  | (R1,R2) (48, 8) |  #params 25168 | approx 1.608e-15  | approx.bound 6.802e-06
# 1  | (R1,R2) (48, 8) |  #params 25168 | approx 1.251e-15  | approx.bound 6.802e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 376.4755063035591 | Predefined Bound 376.6140000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 27
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [34, 2]
# 0  | (R1,R2) (34, 2) |  #params 22818 | approx 0.01706  | approx.bound 0.01725
# 1  | (R1,R2) (34, 2) |  #params 22818 | approx 0.01706  | approx.bound 0.01725
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [63, 4]
# 0  | (R1,R2) (63, 4) |  #params 20428 | approx 0.0001571  | approx.bound 0.0001945
# 1  | (R1,R2) (63, 4) |  #params 20428 | approx 0.0001571  | approx.bound 0.0001945
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [95, 8]
# 0  | (R1,R2) (95, 8) |  #params 24194 | approx 3.671e-05  | approx.bound 3.739e-05
# 1  | (R1,R2) (95, 8) |  #params 24194 | approx 3.671e-05  | approx.bound 3.739e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [64, 16]
# 0  | (R1,R2) (64, 16) |  #params 16512 | approx -1.22e-15  | approx.bound 6.781e-07
# 1  | (R1,R2) (64, 16) |  #params 16512 | approx -9.148e-16  | approx.bound 6.781e-07
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 418.82797970124375 | Predefined Bound 418.8441600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 28
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 7048 | approx 0.01732  | approx.bound 0.01744
# 1  | (R1,R2) (12, 2) |  #params 7048 | approx 0.01732  | approx.bound 0.01744
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [39, 4]
# 0  | (R1,R2) (39, 4) |  #params 6100 | approx 0.0001193  | approx.bound 0.0001271
# 1  | (R1,R2) (39, 4) |  #params 6100 | approx 0.0001193  | approx.bound 0.0001271
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [31, 8]
# 0  | (R1,R2) (31, 8) |  #params 4683 | approx 4.346e-06  | approx.bound 7.758e-06
# 1  | (R1,R2) (31, 8) |  #params 4683 | approx 4.346e-06  | approx.bound 7.758e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 264.19641842133933 | Predefined Bound 264.2472000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 29
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [17, 2]
# 0  | (R1,R2) (17, 2) |  #params 10119 | approx 0.01347  | approx.bound 0.01363
# 1  | (R1,R2) (17, 2) |  #params 10119 | approx 0.01347  | approx.bound 0.01363
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [27, 4]
# 0  | (R1,R2) (27, 4) |  #params 3985 | approx 0.0001447  | approx.bound 0.0001615
# 1  | (R1,R2) (27, 4) |  #params 3985 | approx 0.0001447  | approx.bound 0.0001615
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 8]
# 0  | (R1,R2) (24, 8) |  #params 2776 | approx 1.552e-05  | approx.bound 1.672e-05
# 1  | (R1,R2) (24, 8) |  #params 2776 | approx 1.552e-05  | approx.bound 1.672e-05
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 454.8906913051469 | Predefined Bound 454.9003200000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 30
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 1152 | approx 0.005225  | approx.bound 0.005825
# 1  | (R1,R2) (2, 1) |  #params 1152 | approx 0.005225  | approx.bound 0.005825
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 102 | approx 0.0002838  | approx.bound 0.0006028
# 1  | (R1,R2) (2, 1) |  #params 102 | approx 0.0002838  | approx.bound 0.0006028
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 14 | approx 8.573e-05  | approx.bound 0.000319
# 1  | (R1,R2) (1, 1) |  #params 14 | approx 8.573e-05  | approx.bound 0.000319
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 353.5545555016215 | Predefined Bound 368.2173600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 31
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 2]
# 0  | (R1,R2) (15, 2) |  #params 20179 | approx 0.02957  | approx.bound 0.03016
# 1  | (R1,R2) (15, 2) |  #params 20179 | approx 0.02957  | approx.bound 0.03016
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 3]
# 0  | (R1,R2) (14, 3) |  #params 978 | approx 0.0004269  | approx.bound 0.000614
# 1  | (R1,R2) (14, 3) |  #params 978 | approx 0.0004269  | approx.bound 0.000614
# 2  | (R1,R2) (14, 3) |  #params 978 | approx 0.0004269  | approx.bound 0.000614
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 6]
# 0  | (R1,R2) (7, 6) |  #params 316 | approx 9.401e-05  | approx.bound 0.0001872
# 1  | (R1,R2) (7, 6) |  #params 316 | approx 9.401e-05  | approx.bound 0.0001872
# Approximation Error [615.05779742 615.05779742] | Predefined Bound 616.9060800000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 32
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 47135 | approx 0.005731  | approx.bound 0.006904
# 1  | (R1,R2) (7, 2) |  #params 47135 | approx 0.005731  | approx.bound 0.006904
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [43, 3]
# 0  | (R1,R2) (43, 3) |  #params 33079 | approx 0.001165  | approx.bound 0.00118
# 1  | (R1,R2) (43, 3) |  #params 33079 | approx 0.001165  | approx.bound 0.00118
# 2  | (R1,R2) (43, 3) |  #params 33079 | approx 0.001165  | approx.bound 0.00118
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [120, 6]
# 0  | (R1,R2) (120, 6) |  #params 43116 | approx 1.334e-05  | approx.bound 1.444e-05
# 1  | (R1,R2) (120, 6) |  #params 43116 | approx 1.334e-05  | approx.bound 1.444e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [48, 12]
# 0  | (R1,R2) (48, 12) |  #params 19728 | approx 2.251e-16  | approx.bound 1.094e-06
# 1  | (R1,R2) (48, 12) |  #params 19728 | approx 5.627e-16  | approx.bound 1.094e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 449.3964613184362 | Predefined Bound 449.4672000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 33
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [28, 2]
# 0  | (R1,R2) (28, 2) |  #params 37440 | approx 0.02146  | approx.bound 0.02315
# 1  | (R1,R2) (28, 2) |  #params 37440 | approx 0.02146  | approx.bound 0.02315
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [74, 4]
# 0  | (R1,R2) (74, 4) |  #params 38200 | approx 0.001684  | approx.bound 0.001728
# 1  | (R1,R2) (74, 4) |  #params 38200 | approx 0.001684  | approx.bound 0.001728
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [135, 8]
# 0  | (R1,R2) (135, 8) |  #params 49474 | approx 4.05e-05  | approx.bound 4.358e-05
# 1  | (R1,R2) (135, 8) |  #params 49474 | approx 4.05e-05  | approx.bound 4.358e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [48, 16]
# 0  | (R1,R2) (48, 16) |  #params 22000 | approx -3.154e-16  | approx.bound 3.08e-06
# 1  | (R1,R2) (48, 16) |  #params 22000 | approx 4.731e-16  | approx.bound 3.08e-06
# Approximation Error [273.34919065 273.34919065] | Predefined Bound 273.3847200000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 34
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [27, 2]
# 0  | (R1,R2) (27, 2) |  #params 15772 | approx 0.04024  | approx.bound 0.04056
# 1  | (R1,R2) (27, 2) |  #params 15772 | approx 0.04024  | approx.bound 0.04056
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [53, 4]
# 0  | (R1,R2) (53, 4) |  #params 16446 | approx 0.00027  | approx.bound 0.0003364
# 1  | (R1,R2) (53, 4) |  #params 16446 | approx 0.00027  | approx.bound 0.0003364
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [95, 8]
# 0  | (R1,R2) (95, 8) |  #params 22294 | approx 6.483e-05  | approx.bound 6.639e-05
# 1  | (R1,R2) (95, 8) |  #params 22294 | approx 6.483e-05  | approx.bound 6.639e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [64, 16]
# 0  | (R1,R2) (64, 16) |  #params 16512 | approx -1.622e-15  | approx.bound 1.555e-06
# 1  | (R1,R2) (64, 16) |  #params 16512 | approx -1.216e-15  | approx.bound 1.555e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 189.65830361653934 | Predefined Bound 189.66528000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 35
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [23, 1]
# 0  | (R1,R2) (19, 1) |  #params 14157 | approx 0.02294  | approx.bound 0.023
# 1  | (R1,R2) (19, 1) |  #params 14157 | approx 0.02294  | approx.bound 0.023
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [20, 2]
# 0  | (R1,R2) (20, 2) |  #params 1784 | approx 6.02e-05  | approx.bound 6.286e-05
# 1  | (R1,R2) (20, 2) |  #params 1784 | approx 6.02e-05  | approx.bound 6.286e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 4]
# 0  | (R1,R2) (15, 4) |  #params 856 | approx 1.761e-06  | approx.bound 2.66e-06
# 1  | (R1,R2) (15, 4) |  #params 856 | approx 1.761e-06  | approx.bound 2.66e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 641.0836900560607 | Predefined Bound 641.1081600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 36
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1693 | approx 0.003129  | approx.bound 0.005749
# 1  | (R1,R2) (1, 1) |  #params 1693 | approx 0.003129  | approx.bound 0.005749
# 2  | (R1,R2) (1, 1) |  #params 1693 | approx 0.003129  | approx.bound 0.005749
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 7.665e-07  | approx.bound 0.002628
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 7.665e-07  | approx.bound 0.002628
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 224.1216550473182 | Predefined Bound 411.68232000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 37
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 1]
# 0  | (R1,R2) (23, 1) |  #params 10651 | approx 0.01579  | approx.bound 0.01589
# 1  | (R1,R2) (23, 1) |  #params 10651 | approx 0.01579  | approx.bound 0.01589
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [49, 2]
# 0  | (R1,R2) (49, 2) |  #params 9167 | approx 9.83e-05  | approx.bound 0.0001032
# 1  | (R1,R2) (49, 2) |  #params 9167 | approx 9.83e-05  | approx.bound 0.0001032
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 4]
# 0  | (R1,R2) (24, 4) |  #params 4120 | approx -4.619e-16  | approx.bound 4.94e-06
# 1  | (R1,R2) (24, 4) |  #params 4120 | approx 0  | approx.bound 4.94e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 381.4364634711419 | Predefined Bound 381.5532000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 38
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [19, 2]
# 0  | (R1,R2) (19, 2) |  #params 50031 | approx 0.02369  | approx.bound 0.02399
# 1  | (R1,R2) (19, 2) |  #params 50031 | approx 0.02369  | approx.bound 0.02399
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [56, 4]
# 0  | (R1,R2) (56, 4) |  #params 51592 | approx 0.0002043  | approx.bound 0.0003062
# 1  | (R1,R2) (56, 4) |  #params 51592 | approx 0.0002043  | approx.bound 0.0003062
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [148, 8]
# 0  | (R1,R2) (148, 8) |  #params 67552 | approx 0.0001012  | approx.bound 0.000102
# 1  | (R1,R2) (148, 8) |  #params 67552 | approx 0.0001012  | approx.bound 0.000102
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [96, 16]
# 0  | (R1,R2) (96, 16) |  #params 52096 | approx 1.799e-15  | approx.bound 7.369e-07
# 1  | (R1,R2) (96, 16) |  #params 52096 | approx 1.635e-15  | approx.bound 7.369e-07
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 546.753044180321 | Predefined Bound 546.7694400000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 39
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 1]
# 0  | (R1,R2) (14, 1) |  #params 5028 | approx 0.04182  | approx.bound 0.04219
# 1  | (R1,R2) (14, 1) |  #params 5028 | approx 0.04182  | approx.bound 0.04219
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 1132 | approx 0.0003601  | approx.bound 0.000382
# 1  | (R1,R2) (12, 2) |  #params 1132 | approx 0.0003601  | approx.bound 0.000382
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 4]
# 0  | (R1,R2) (7, 4) |  #params 324 | approx 8.035e-06  | approx.bound 2.195e-05
# 1  | (R1,R2) (7, 4) |  #params 324 | approx 8.035e-06  | approx.bound 2.195e-05
# Approximation Error [295.02395226 295.02395226] | Predefined Bound 295.1172
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 40
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [27, 1]
# 0  | (R1,R2) (15, 1) |  #params 17177 | approx 0.01735  | approx.bound 0.01752
# 1  | (R1,R2) (15, 1) |  #params 17177 | approx 0.01735  | approx.bound 0.01752
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 428 | approx -4.687e-16  | approx.bound 0.0001812
# 1  | (R1,R2) (8, 2) |  #params 428 | approx -3.515e-16  | approx.bound 0.0001812
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 274.0293933966186 | Predefined Bound 276.8421600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 41
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 2692 | approx 0.01331  | approx.bound 0.01412
# 1  | (R1,R2) (2, 1) |  #params 2692 | approx 0.01331  | approx.bound 0.01412
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 22 | approx 9.017e-06  | approx.bound 0.0008115
# 1  | (R1,R2) (2, 1) |  #params 22 | approx 9.017e-06  | approx.bound 0.0008115
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 324.6306575045601 | Predefined Bound 326.23416000000003
# --------------------------------------------------------------------
# TT uses 584348 parameters, compression ratio = 0.2012

# %%
np.prod(image.shape)
# Out:
# np.int64(187500)

# %%
reshape_for_tt
# Out:
# True

# %%
print(len(denoised_patches))
# print(denoised_patches[0][0])
# Out:
# 41

# %%
# 5. Reconstruct image
# Averaging
reconstructed = reconstruct_image_from_patches(
    denoised_patches, segments, noisy.shape, patch_size=patch_size
)
# # Using Marginal Median (High (resistant) to outliers), sharpens edge)
# recon_med = reconstruct_image_from_patches_median(
#     denoised_patches, segments, noisy.shape, patch_size=patch_size
# )  # Resists outlier

# %%
reconstructed_image = np.clip(reconstructed, 0, 1)
# reconstructed_image_med = np.clip(recon_med, 0, 1)

# %%
print(reconstructed_image.shape)
plt.imshow(reconstructed_image)
# Out:
# (250, 250, 3)

# %%
# print(reconstructed_image_med.shape)
# plt.imshow(reconstructed_image_med)

# %%
# 6. Compute metrics
psnr, ssim = compute_quality_metrics(
    original=image, 
    reconstructed=reconstructed_image
)
print(f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}")

# psnr, ssim = compute_quality_metrics(
#     original=image, 
#     reconstructed=reconstructed_image_med
# )
# print(f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}")
# Out:
# PSNR: 22.38, SSIM: 0.8629
