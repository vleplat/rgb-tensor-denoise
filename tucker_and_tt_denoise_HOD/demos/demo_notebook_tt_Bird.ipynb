# %% [markdown]
# ## 🧩 Image Reconstruction
#
# This task focuses on **image denoising and reconstruction** using local low-rank **tensor decomposition** (Tucker or Tensor Train) within segmented image regions.
#
# ---
#
# ### 🖼️ Problem Setup
#
# You are given a **color image** $ Y \in \mathbb{R}^{I \times J \times 3}$ that is degraded by **Gaussian noise** with:
# - Mean = 0
# - Standard deviation = $ \sigma $
#
# ---
#
# ### 🧱 Step-by-Step Instructions
#
# #### **(a) Superpixel Clustering / Segmentation**
#
# - Segment the noisy image $ Y $ using a superpixel clustering algorithm (e.g., SLIC).
# - This produces clusters (segments) of pixels with similar appearance.
#
# #### **(b) Patch Tensor Construction + Low-Rank Approximation**
#
# For **each segment**:
#
# 1. **Extract patches**:
#    - For each pixel in the segment, extract a centered patch of size $ d \times d \times 3 $.
#    - Stack all patches into a tensor:
#      $
#      X \in \mathbb{R}^{d \times d \times 3 \times K}
#      $
#      where $K $ is the number of pixels (patches) in the segment.
#
# 2. **Denoise using a low-rank tensor model**:
#    - Approximate $ X $ using a **Tucker** or **Tensor Train (TT)** decomposition:
#      $
#      \hat{X} \approx X
#      $
#    - Subject to a reconstruction error bound:
#      $
#      \| X - \hat{X} \|_F^2 \leq \epsilon^2 = 3\sigma^2 d^2 K
#      $
#    - Goal: minimize the **number of parameters** in $ \hat{X} $.
#
# 2. **Notes**:
#   - For TT: two methods can be used
#     - TT decomposition with fixed ranks
#     - TT decomposition with error bounded constraints -> it computes the best TT ranks so that the error of approximation is bounded (for each patch)
#   - For each method, we have the choice of the shape
#     - One may keep the orginal 4-th order format of $X$
#     - One can reshape it into a 6-th order tensor format, then compute the TT decomposition. The motivation is to take advantage of TT compression capabilities for high-order tensors, in other words to obtain higher compression
#   - Parameters to play with:
#     - the value of $\sigma$ - for real life noisy signals, we have to try different values
#     - the value of $d$ - this has an impact on the smoothing since higher value for $d$ leads to higher overlapping for the aggregation steps. (cell ""3. Extract patches per superpixel"")
#     - activate or not the 6-th order reshaping: set parameter "reshape_for_tt" to False or True (cell"" 4. Denoise each patch GROUP27"")
#     - n_segments for superpixel method (cell "2. Superpixel segmentation")
#
# ---
#
# #### **(c) Reconstruct the Image**
#
# 1. Place denoised patches back into their original image locations.
# 2. Average overlapping regions.
# 3. Compute reconstruction quality metrics:
#    - **PSNR** (Peak Signal-to-Noise Ratio)
#    - **SSIM** (Structural Similarity Index)
#
# ---
#
# ### 🎯 Goal
#
# Reconstruct a **high-quality, denoised image** by leveraging **local patch redundancy** through **low-rank tensor decompositions** on segments of the image.

# %%
from IPython.display import Image, display

# Display with controlled width/height
display(Image(filename="../Datasets/illustration_superpixel.png", width=500, height=300))

# %% [markdown]
# Figure 1: Illustration of centroid superpixel sampling
#
# ---

# %% [markdown]
# We can start now )

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('.'))))

import numpy as np
import matplotlib.pyplot as plt
from tucker_and_tt_denoise_HOD import (
    load_image, add_gaussian_noise,
    superpixel_segmentation, extract_clustered_patches,
    tucker_decompose_and_denoise, reconstruct_image_from_patches,
    compute_quality_metrics, decompose_and_denoise_patch,tt_num_parameters,
    tt_compression_ratio
)

# %% [markdown]
# A very simple test before on a small patch

# %%
# Single patch test (4D)
patch = np.random.rand(6, 6, 3, 20)  # (h, w, C)

# Test Tucker
X_hat, (G, U), reshape_for_tt = decompose_and_denoise_patch(patch, method='tucker', sigma=0.1, reshape_for_tt=False)
print(X_hat.shape)  # Should return (6, 6, 3, 20)
print(G.shape, len(U))
# Out:
# 17.228045059202827 bound 21.600000000000005
# Ranks [6, 6, 3, 16]
# (6, 6, 3, 20)
# (6, 6, 3, 16) 4

# %%
# Test TT adaptative without 6-order reshape
X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch, method='tt_adaptive', sigma=0.1, reshape_for_tt=False, target_order=6)
print(X_hat.shape, len(tt_tensor), reshape_for_tt)
# Out:
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 6]
# 0  | (R1,R2) (16, 6) |  #params 2084 | approx 0.0239  | approx.bound 0.03146
# 1  | (R1,R2) (16, 6) |  #params 2084 | approx 0.0239  | approx.bound 0.03146
# Perform the 2-th Tucker-2 decomposition
# Approximation Error 21.6878694634795 | Predefined Bound 22.680000000000007
# (6, 6, 3, 20) 4 False

# %%
# Test TT adaptative with 6-order reshape
X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch, method='tt_adaptive', sigma=0.1, reshape_for_tt=True, target_order=6)
print(X_hat.shape, len(tt_tensor), reshape_for_tt)
# Out:
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [23, 2]
# 0  | (R1,R2) (23, 2) |  #params 2143 | approx 0.02811  | approx.bound 0.03146
# 1  | (R1,R2) (23, 2) |  #params 2143 | approx 0.02811  | approx.bound 0.03146
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 4]
# 0  | (R1,R2) (16, 4) |  #params 1376 | approx 0  | approx.bound 0.003455
# 1  | (R1,R2) (16, 4) |  #params 1376 | approx -4.868e-16  | approx.bound 0.003455
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 20.259234161425752 | Predefined Bound 22.680000000000007
# (6, 6, 3, 20) 6 True

# %% [markdown]
# Now, we can start playing with a true RGB image

# %%
# 1. Load image + add noise
# image = load_image("../Datasets/cat1.jpg")       # Replace with your  image
# image = load_image("../Datasets/baboon.bmp")     # Replace with your image
image = load_image("../Datasets/parrot_small.jpg") # Replace with your image
# image = load_image("Datasets/ara.jpeg")


mean, sigma = 0, 0.07
noisy = add_gaussian_noise(image, mean, sigma)

plt.imshow(image)
plt.show()

plt.imshow(noisy)
plt.show()

# %%
# 2. Superpixel segmentation
# segments = superpixel_segmentation(noisy, n_segments=100, compactness=20) # lower level seg for SR, 2000 for higher level
# segments = superpixel_segmentation(noisy, n_segments=10, compactness=30)
segments = superpixel_segmentation(noisy, n_segments=50, compactness=30)

# %%
from skimage.segmentation import mark_boundaries
# plt.figure(figsize=(5, 5))
plt.subplot(1, 2, 1)
plt.imshow(noisy)
plt.subplot(1, 2, 2)
plt.imshow(mark_boundaries(noisy, segments))
plt.show()

# %%
# 3. Extract patches per superpixel
d = 5
patch_size = d  # Adjust based on tiling artifact size
patches = extract_clustered_patches(noisy, segments, patch_size=patch_size)

# %%
len(patches), patches[0][1].shape
# Out:
# (41, (4, 4, 3, 905))

# %%
# 4. Denoise each patch GROUP (order-4 tensor or order-6) - TT
denoised_patches = []
denoised_patches_factors = []
total_params = 0
original_params = 0
# sigma = 0.01 # for SR

for segidx, patch_group in patches:
    # patch_group shape: (h, w, C, num_patches)
    print(f'--------------------------------------------------------------------')
    print(f'Decomposing for segment {segidx}')
    # X_hat, G, U = tucker_decompose_and_denoise(patch_group, sigma) # Tucker
    X_hat, tt_tensor, reshape_for_tt = decompose_and_denoise_patch(patch_group, method='tt_adaptive', sigma = sigma, reshape_for_tt=True, target_order=10)
    denoised_patches.append((segidx, X_hat))
    denoised_patches_factors.append((segidx, tt_tensor))
    total_params = total_params + tt_num_parameters(tt_tensor)
    original_params = original_params + np.prod(patch_group.shape)
    print(f'--------------------------------------------------------------------')

ratio = total_params / original_params
print(f"TT uses {total_params} parameters, compression ratio = {ratio:.4f}")
# Out:
# --------------------------------------------------------------------
# Decomposing for segment 1
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [5, 1]
# 0  | (R1,R2) (5, 1) |  #params 1507 | approx 0.05449  | approx.bound 0.05567
# 1  | (R1,R2) (5, 1) |  #params 1507 | approx 0.05449  | approx.bound 0.05567
# 2  | (R1,R2) (5, 1) |  #params 1507 | approx 0.05449  | approx.bound 0.05567
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [3, 1]
# 0  | (R1,R2) (3, 1) |  #params 113 | approx 0.000933  | approx.bound 0.001244
# 1  | (R1,R2) (3, 1) |  #params 113 | approx 0.000933  | approx.bound 0.001244
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 2]
# 0  | (R1,R2) (2, 2) |  #params 30 | approx 4.012e-06  | approx.bound 0.0003116
# 1  | (R1,R2) (2, 2) |  #params 30 | approx 4.012e-06  | approx.bound 0.0003116
# Approximation Error [222.33218694 222.33218694] | Predefined Bound 223.49880000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 2
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 1]
# 0  | (R1,R2) (4, 1) |  #params 20206 | approx 0.05663  | approx.bound 0.05899
# 1  | (R1,R2) (4, 1) |  #params 20206 | approx 0.05663  | approx.bound 0.05899
# 2  | (R1,R2) (4, 1) |  #params 20206 | approx 0.05663  | approx.bound 0.05899
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [23, 2]
# 0  | (R1,R2) (23, 2) |  #params 17208 | approx 0.002084  | approx.bound 0.002503
# 1  | (R1,R2) (23, 2) |  #params 17208 | approx 0.002084  | approx.bound 0.002503
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [65, 4]
# 0  | (R1,R2) (65, 4) |  #params 16851 | approx 0.0003916  | approx.bound 0.0004196
# 1  | (R1,R2) (65, 4) |  #params 16851 | approx 0.0003916  | approx.bound 0.0004196
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [45, 8]
# 0  | (R1,R2) (45, 8) |  #params 10999 | approx 2.002e-05  | approx.bound 2.804e-05
# 1  | (R1,R2) (45, 8) |  #params 10999 | approx 2.002e-05  | approx.bound 2.804e-05
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 570.4046412075659 | Predefined Bound 570.4776000000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 3
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 4365 | approx 0.0218  | approx.bound 0.02219
# 1  | (R1,R2) (7, 2) |  #params 4365 | approx 0.0218  | approx.bound 0.02219
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [6, 2]
# 0  | (R1,R2) (6, 2) |  #params 230 | approx 0.0002502  | approx.bound 0.0003945
# 1  | (R1,R2) (6, 2) |  #params 230 | approx 0.0002502  | approx.bound 0.0003945
# 2  | (R1,R2) (6, 2) |  #params 230 | approx 0.0002502  | approx.bound 0.0003945
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [3, 3]
# 0  | (R1,R2) (3, 3) |  #params 66 | approx 3.477e-05  | approx.bound 0.0001444
# 1  | (R1,R2) (3, 3) |  #params 66 | approx 3.477e-05  | approx.bound 0.0001444
# Approximation Error [259.03869755 259.0386975 ] | Predefined Bound 260.29584000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 4
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 5560 | approx 0.009441  | approx.bound 0.009488
# 1  | (R1,R2) (12, 2) |  #params 5560 | approx 0.009441  | approx.bound 0.009488
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 4]
# 0  | (R1,R2) (24, 4) |  #params 2608 | approx 4.466e-05  | approx.bound 4.776e-05
# 1  | (R1,R2) (24, 4) |  #params 2608 | approx 4.466e-05  | approx.bound 4.776e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 8]
# 0  | (R1,R2) (15, 8) |  #params 1384 | approx 2.496e-06  | approx.bound 3.099e-06
# 1  | (R1,R2) (15, 8) |  #params 1384 | approx 2.496e-06  | approx.bound 3.099e-06
# Approximation Error [275.3430838 275.3430838] | Predefined Bound 275.3604000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 5
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [37, 1]
# 0  | (R1,R2) (19, 1) |  #params 22479 | approx 0.01936  | approx.bound 0.01949
# 1  | (R1,R2) (19, 1) |  #params 22479 | approx 0.01936  | approx.bound 0.01949
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 524 | approx 1.263e-16  | approx.bound 0.000134
# 1  | (R1,R2) (8, 2) |  #params 524 | approx 3.789e-16  | approx.bound 0.000134
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 284.29709787424326 | Predefined Bound 286.22664000000003
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 6
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 6572 | approx 0.01347  | approx.bound 0.01348
# 1  | (R1,R2) (8, 2) |  #params 6572 | approx 0.01347  | approx.bound 0.01348
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 4]
# 0  | (R1,R2) (24, 4) |  #params 6736 | approx -9.491e-16  | approx.bound 3.959e-06
# 1  | (R1,R2) (24, 4) |  #params 6736 | approx -8.305e-16  | approx.bound 3.959e-06
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [48, 8]
# 0  | (R1,R2) (48, 8) |  #params 8512 | approx 3.559e-16  | approx.bound 3.959e-06
# 1  | (R1,R2) (48, 8) |  #params 8512 | approx 1.186e-16  | approx.bound 3.959e-06
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [61, 16]
# 0  | (R1,R2) (61, 16) |  #params 10016 | approx 2.805e-06  | approx.bound 3.959e-06
# 1  | (R1,R2) (61, 16) |  #params 10016 | approx 2.805e-06  | approx.bound 3.959e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 209.4043917323579 | Predefined Bound 209.42208000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 7
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1173 | approx 0.003003  | approx.bound 0.005662
# 1  | (R1,R2) (1, 1) |  #params 1173 | approx 0.003003  | approx.bound 0.005662
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 2.399e-06  | approx.bound 0.002668
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 2.399e-06  | approx.bound 0.002668
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 150.35250713230198 | Predefined Bound 283.26312
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 8
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 369 | approx 0.1595  | approx.bound 0.183
# 1  | (R1,R2) (1, 1) |  #params 369 | approx 0.1595  | approx.bound 0.183
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 31 | approx 0.01609  | approx.bound 0.02794
# 1  | (R1,R2) (1, 1) |  #params 31 | approx 0.01609  | approx.bound 0.02794
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 2]
# 0  | (R1,R2) (1, 2) |  #params 16 | approx 1.325e-05  | approx.bound 0.01204
# 1  | (R1,R2) (1, 2) |  #params 16 | approx 1.325e-05  | approx.bound 0.01204
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 296.6086202987515 | Predefined Bound 313.6392000000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 9
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [3, 1]
# 0  | (R1,R2) (3, 1) |  #params 1565 | approx 0.005699  | approx.bound 0.006449
# 1  | (R1,R2) (3, 1) |  #params 1565 | approx 0.005699  | approx.bound 0.006449
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [2, 1]
# 0  | (R1,R2) (2, 1) |  #params 44 | approx 7.532e-05  | approx.bound 0.0007542
# 1  | (R1,R2) (2, 1) |  #params 44 | approx 7.532e-05  | approx.bound 0.0007542
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 10 | approx 0.0001033  | approx.bound 0.0006789
# 1  | (R1,R2) (1, 1) |  #params 10 | approx 0.0001033  | approx.bound 0.0006789
# Approximation Error [303.13381955 303.13381955] | Predefined Bound 332.65512000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 10
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [13, 2]
# 0  | (R1,R2) (13, 2) |  #params 9689 | approx 0.01592  | approx.bound 0.01613
# 1  | (R1,R2) (13, 2) |  #params 9689 | approx 0.01592  | approx.bound 0.01613
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 4]
# 0  | (R1,R2) (12, 4) |  #params 868 | approx 0.0001766  | approx.bound 0.0002144
# 1  | (R1,R2) (12, 4) |  #params 868 | approx 0.0001766  | approx.bound 0.0002144
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 8]
# 0  | (R1,R2) (8, 8) |  #params 384 | approx 1.722e-05  | approx.bound 3.786e-05
# 1  | (R1,R2) (8, 8) |  #params 384 | approx 1.722e-05  | approx.bound 3.786e-05
# Approximation Error [320.1505805 320.1505805] | Predefined Bound 320.55408000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 11
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1425 | approx 0.001789  | approx.bound 0.005444
# 1  | (R1,R2) (1, 1) |  #params 1425 | approx 0.001789  | approx.bound 0.005444
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 8.126e-08  | approx.bound 0.003662
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 8.126e-08  | approx.bound 0.003662
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 113.53886917422642 | Predefined Bound 345.4970400000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 12
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [17, 2]
# 0  | (R1,R2) (17, 2) |  #params 16137 | approx 0.03894  | approx.bound 0.04021
# 1  | (R1,R2) (17, 2) |  #params 16137 | approx 0.03894  | approx.bound 0.04021
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [21, 4]
# 0  | (R1,R2) (21, 4) |  #params 1759 | approx 0.0007332  | approx.bound 0.001314
# 1  | (R1,R2) (21, 4) |  #params 1759 | approx 0.0007332  | approx.bound 0.001314
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [11, 8]
# 0  | (R1,R2) (11, 8) |  #params 702 | approx 4.574e-05  | approx.bound 0.0005809
# 1  | (R1,R2) (11, 8) |  #params 702 | approx 4.574e-05  | approx.bound 0.0005809
# Approximation Error [415.92826771 415.92826771] | Predefined Bound 421.31376000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 13
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [18, 2]
# 0  | (R1,R2) (18, 2) |  #params 9382 | approx 0.06025  | approx.bound 0.06177
# 1  | (R1,R2) (18, 2) |  #params 9382 | approx 0.06025  | approx.bound 0.06177
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 4]
# 0  | (R1,R2) (16, 4) |  #params 1648 | approx 0.00151  | approx.bound 0.001617
# 1  | (R1,R2) (16, 4) |  #params 1648 | approx 0.00151  | approx.bound 0.001617
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [13, 8]
# 0  | (R1,R2) (13, 8) |  #params 896 | approx 6.158e-05  | approx.bound 0.0001069
# 1  | (R1,R2) (13, 8) |  #params 896 | approx 6.158e-05  | approx.bound 0.0001069
# Approximation Error [279.11930738 279.11930738] | Predefined Bound 279.31176000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 14
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 1]
# 0  | (R1,R2) (10, 1) |  #params 9252 | approx 0.04974  | approx.bound 0.05018
# 1  | (R1,R2) (10, 1) |  #params 9252 | approx 0.04974  | approx.bound 0.05018
# 2  | (R1,R2) (10, 1) |  #params 9252 | approx 0.04974  | approx.bound 0.05018
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 326 | approx 0.0004569  | approx.bound 0.0004575
# 1  | (R1,R2) (7, 2) |  #params 326 | approx 0.0004569  | approx.bound 0.0004575
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 4]
# 0  | (R1,R2) (8, 4) |  #params 192 | approx 0  | approx.bound 6.115e-07
# 1  | (R1,R2) (8, 4) |  #params 192 | approx -2.218e-16  | approx.bound 6.115e-07
# Approximation Error [433.16282627 433.16282627] | Predefined Bound 433.16784000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 15
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [31, 2]
# 0  | (R1,R2) (31, 2) |  #params 15969 | approx 0.01663  | approx.bound 0.01706
# 1  | (R1,R2) (31, 2) |  #params 15969 | approx 0.01663  | approx.bound 0.01706
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [36, 4]
# 0  | (R1,R2) (36, 4) |  #params 5668 | approx 0.0004273  | approx.bound 0.0004332
# 1  | (R1,R2) (36, 4) |  #params 5668 | approx 0.0004273  | approx.bound 0.0004332
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [30, 8]
# 0  | (R1,R2) (30, 8) |  #params 3184 | approx 4.939e-06  | approx.bound 5.828e-06
# 1  | (R1,R2) (30, 8) |  #params 3184 | approx 4.939e-06  | approx.bound 5.828e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 319.05597528115686 | Predefined Bound 319.07232000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 16
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 22412 | approx 0.0117  | approx.bound 0.01215
# 1  | (R1,R2) (8, 2) |  #params 22412 | approx 0.0117  | approx.bound 0.01215
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 3]
# 0  | (R1,R2) (7, 3) |  #params 264 | approx 0.0001408  | approx.bound 0.0004536
# 1  | (R1,R2) (7, 3) |  #params 264 | approx 0.0001408  | approx.bound 0.0004536
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 662.5850342181802 | Predefined Bound 679.8808800000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 17
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 10432 | approx 0.01802  | approx.bound 0.01832
# 1  | (R1,R2) (12, 2) |  #params 10432 | approx 0.01802  | approx.bound 0.01832
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [11, 3]
# 0  | (R1,R2) (11, 3) |  #params 672 | approx 0.0002838  | approx.bound 0.0003007
# 1  | (R1,R2) (11, 3) |  #params 672 | approx 0.0002838  | approx.bound 0.0003007
# 2  | (R1,R2) (11, 3) |  #params 672 | approx 0.0002838  | approx.bound 0.0003007
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 6]
# 0  | (R1,R2) (7, 6) |  #params 274 | approx 1.09e-05  | approx.bound 1.689e-05
# 1  | (R1,R2) (7, 6) |  #params 274 | approx 1.09e-05  | approx.bound 1.689e-05
# Approximation Error [381.6775819 381.6775819] | Predefined Bound 381.80016000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 18
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 681 | approx 0.002945  | approx.bound 0.005608
# 1  | (R1,R2) (1, 1) |  #params 681 | approx 0.002945  | approx.bound 0.005608
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 13 | approx 4.958e-05  | approx.bound 0.00267
# 1  | (R1,R2) (1, 1) |  #params 13 | approx 4.958e-05  | approx.bound 0.00267
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 6 | approx 1.648e-06  | approx.bound 0.002621
# 1  | (R1,R2) (1, 1) |  #params 6 | approx 1.648e-06  | approx.bound 0.002621
# Approximation Error [166.52614036 166.52614036] | Predefined Bound 311.66352
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 19
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [19, 2]
# 0  | (R1,R2) (19, 2) |  #params 7623 | approx 0.01135  | approx.bound 0.01153
# 1  | (R1,R2) (19, 2) |  #params 7623 | approx 0.01135  | approx.bound 0.01153
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [21, 4]
# 0  | (R1,R2) (21, 4) |  #params 2221 | approx 0.0001842  | approx.bound 0.0001889
# 1  | (R1,R2) (21, 4) |  #params 2221 | approx 0.0001842  | approx.bound 0.0001889
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 8]
# 0  | (R1,R2) (16, 8) |  #params 1328 | approx 7.803e-16  | approx.bound 4.716e-06
# 1  | (R1,R2) (16, 8) |  #params 1328 | approx 3.344e-16  | approx.bound 4.716e-06
# Approximation Error [190.32920054 190.32920054] | Predefined Bound 190.40616000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 20
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 7216 | approx 0.1091  | approx.bound 0.1092
# 1  | (R1,R2) (12, 2) |  #params 7216 | approx 0.1091  | approx.bound 0.1092
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [25, 4]
# 0  | (R1,R2) (25, 4) |  #params 2116 | approx 0.0001209  | approx.bound 0.0001332
# 1  | (R1,R2) (25, 4) |  #params 2116 | approx 0.0001209  | approx.bound 0.0001332
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 8]
# 0  | (R1,R2) (16, 8) |  #params 1520 | approx 8.235e-16  | approx.bound 1.236e-05
# 1  | (R1,R2) (16, 8) |  #params 1520 | approx 1.153e-15  | approx.bound 1.236e-05
# Approximation Error [338.54802461 338.54802461] | Predefined Bound 338.5821600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 21
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 2]
# 0  | (R1,R2) (14, 2) |  #params 11190 | approx 0.01476  | approx.bound 0.01476
# 1  | (R1,R2) (14, 2) |  #params 11190 | approx 0.01476  | approx.bound 0.01476
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [84, 4]
# 0  | (R1,R2) (84, 4) |  #params 16312 | approx 8.784e-07  | approx.bound 1.081e-06
# 1  | (R1,R2) (84, 4) |  #params 16312 | approx 8.784e-07  | approx.bound 1.081e-06
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [32, 8]
# 0  | (R1,R2) (32, 8) |  #params 9152 | approx 0  | approx.bound 2.027e-07
# 1  | (R1,R2) (32, 8) |  #params 9152 | approx -4.965e-16  | approx.bound 2.027e-07
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 439.08894071442774 | Predefined Bound 439.0948800000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 22
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 11043 | approx 0.09168  | approx.bound 0.09472
# 1  | (R1,R2) (7, 2) |  #params 11043 | approx 0.09168  | approx.bound 0.09472
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [6, 3]
# 0  | (R1,R2) (6, 3) |  #params 210 | approx 0.0007125  | approx.bound 0.003347
# 1  | (R1,R2) (6, 3) |  #params 210 | approx 0.0007125  | approx.bound 0.003347
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 368.061851560743 | Predefined Bound 377.60184000000004
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 23
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 1]
# 0  | (R1,R2) (7, 1) |  #params 4993 | approx 0.006965  | approx.bound 0.007272
# 1  | (R1,R2) (7, 1) |  #params 4993 | approx 0.006965  | approx.bound 0.007272
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [14, 1]
# 0  | (R1,R2) (11, 1) |  #params 1069 | approx 0.0002971  | approx.bound 0.0003088
# 1  | (R1,R2) (11, 1) |  #params 1069 | approx 0.0002971  | approx.bound 0.0003088
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 396 | approx 3.49e-06  | approx.bound 1.173e-05
# 1  | (R1,R2) (8, 2) |  #params 396 | approx 3.49e-06  | approx.bound 1.173e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 2]
# 0  | (R1,R2) (4, 2) |  #params 88 | approx 1.404e-06  | approx.bound 8.244e-06
# 1  | (R1,R2) (4, 2) |  #params 88 | approx 1.404e-06  | approx.bound 8.244e-06
# Approximation Error [283.24536294 283.24536294] | Predefined Bound 283.5100800000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 24
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [47, 2]
# 0  | (R1,R2) (47, 2) |  #params 30836 | approx 0.04897  | approx.bound 0.04948
# 1  | (R1,R2) (47, 2) |  #params 30836 | approx 0.04897  | approx.bound 0.04948
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [88, 4]
# 0  | (R1,R2) (88, 4) |  #params 30816 | approx 0.0004698  | approx.bound 0.0005346
# 1  | (R1,R2) (88, 4) |  #params 30816 | approx 0.0004698  | approx.bound 0.0005346
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [116, 8]
# 0  | (R1,R2) (116, 8) |  #params 35328 | approx 5.699e-05  | approx.bound 6.483e-05
# 1  | (R1,R2) (116, 8) |  #params 35328 | approx 5.699e-05  | approx.bound 6.483e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [64, 16]
# 0  | (R1,R2) (64, 16) |  #params 19200 | approx -1.248e-16  | approx.bound 7.844e-06
# 1  | (R1,R2) (64, 16) |  #params 19200 | approx -1.248e-16  | approx.bound 7.844e-06
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 379.2734004212525 | Predefined Bound 379.3305600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 25
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [20, 1]
# 0  | (R1,R2) (19, 1) |  #params 8229 | approx 0.01255  | approx.bound 0.0126
# 1  | (R1,R2) (19, 1) |  #params 8229 | approx 0.01255  | approx.bound 0.0126
# 2  | (R1,R2) (19, 1) |  #params 8229 | approx 0.01255  | approx.bound 0.0126
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [37, 2]
# 0  | (R1,R2) (37, 2) |  #params 6701 | approx 5.029e-05  | approx.bound 5.258e-05
# 1  | (R1,R2) (37, 2) |  #params 6701 | approx 5.029e-05  | approx.bound 5.258e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 4]
# 0  | (R1,R2) (16, 4) |  #params 2048 | approx 4.153e-16  | approx.bound 2.297e-06
# 1  | (R1,R2) (16, 4) |  #params 2048 | approx 5.538e-16  | approx.bound 2.297e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 335.31132187818366 | Predefined Bound 335.37168
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 26
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [26, 2]
# 0  | (R1,R2) (26, 2) |  #params 15318 | approx 0.01693  | approx.bound 0.01725
# 1  | (R1,R2) (26, 2) |  #params 15318 | approx 0.01693  | approx.bound 0.01725
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [27, 4]
# 0  | (R1,R2) (27, 4) |  #params 6226 | approx 0.0003207  | approx.bound 0.0003259
# 1  | (R1,R2) (27, 4) |  #params 6226 | approx 0.0003207  | approx.bound 0.0003259
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 8]
# 0  | (R1,R2) (15, 8) |  #params 1519 | approx 4.876e-06  | approx.bound 5.198e-06
# 1  | (R1,R2) (15, 8) |  #params 1519 | approx 4.876e-06  | approx.bound 5.198e-06
# Approximation Error [437.35814642 437.35814642] | Predefined Bound 437.3661600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 27
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 21592 | approx 0.01794  | approx.bound 0.01851
# 1  | (R1,R2) (12, 2) |  #params 21592 | approx 0.01794  | approx.bound 0.01851
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [9, 4]
# 0  | (R1,R2) (9, 4) |  #params 484 | approx 5.419e-05  | approx.bound 0.0005865
# 1  | (R1,R2) (9, 4) |  #params 484 | approx 5.419e-05  | approx.bound 0.0005865
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 426.70119354114286 | Predefined Bound 432.42696000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 28
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 4940 | approx 0.01561  | approx.bound 0.01596
# 1  | (R1,R2) (8, 2) |  #params 4940 | approx 0.01561  | approx.bound 0.01596
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [9, 3]
# 0  | (R1,R2) (9, 3) |  #params 444 | approx 0.0003169  | approx.bound 0.0003642
# 1  | (R1,R2) (9, 3) |  #params 444 | approx 0.0003169  | approx.bound 0.0003642
# 2  | (R1,R2) (9, 3) |  #params 444 | approx 0.0003169  | approx.bound 0.0003642
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 5]
# 0  | (R1,R2) (7, 5) |  #params 226 | approx 3.953e-05  | approx.bound 4.73e-05
# 1  | (R1,R2) (7, 5) |  #params 226 | approx 3.953e-05  | approx.bound 4.73e-05
# 2  | (R1,R2) (7, 5) |  #params 226 | approx 3.953e-05  | approx.bound 4.73e-05
# Approximation Error [257.20903307 257.20902368 257.20902368] | Predefined Bound 257.33232000000004
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 29
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1575 | approx 0.003302  | approx.bound 0.005838
# 1  | (R1,R2) (1, 1) |  #params 1575 | approx 0.003302  | approx.bound 0.005838
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 7.767e-07  | approx.bound 0.002545
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 7.767e-07  | approx.bound 0.002545
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 216.39529335227417 | Predefined Bound 382.54104000000007
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 30
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [17, 2]
# 0  | (R1,R2) (17, 2) |  #params 10119 | approx 0.01359  | approx.bound 0.01373
# 1  | (R1,R2) (17, 2) |  #params 10119 | approx 0.01359  | approx.bound 0.01373
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [27, 4]
# 0  | (R1,R2) (27, 4) |  #params 3985 | approx 0.0001405  | approx.bound 0.0001481
# 1  | (R1,R2) (27, 4) |  #params 3985 | approx 0.0001405  | approx.bound 0.0001481
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [28, 8]
# 0  | (R1,R2) (28, 8) |  #params 3228 | approx 5.581e-06  | approx.bound 7.608e-06
# 1  | (R1,R2) (28, 8) |  #params 3228 | approx 5.581e-06  | approx.bound 7.608e-06
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 454.8341129919936 | Predefined Bound 454.9003200000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 31
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [42, 1]
# 0  | (R1,R2) (21, 1) |  #params 54035 | approx 0.03081  | approx.bound 0.03103
# 1  | (R1,R2) (21, 1) |  #params 54035 | approx 0.03081  | approx.bound 0.03103
# 2  | (R1,R2) (21, 1) |  #params 54035 | approx 0.03081  | approx.bound 0.03103
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 572 | approx -1.85e-16  | approx.bound 0.0002212
# 1  | (R1,R2) (8, 2) |  #params 572 | approx -7.401e-16  | approx.bound 0.0002212
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 625.1525945400608 | Predefined Bound 629.5010400000002
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 32
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [7, 2]
# 0  | (R1,R2) (7, 2) |  #params 4295 | approx 0.006177  | approx.bound 0.006416
# 1  | (R1,R2) (7, 2) |  #params 4295 | approx 0.006177  | approx.bound 0.006416
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 3]
# 0  | (R1,R2) (15, 3) |  #params 1047 | approx 0.0002045  | approx.bound 0.0002406
# 1  | (R1,R2) (15, 3) |  #params 1047 | approx 0.0002045  | approx.bound 0.0002406
# 2  | (R1,R2) (15, 3) |  #params 1047 | approx 0.0002045  | approx.bound 0.0002406
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [10, 6]
# 0  | (R1,R2) (10, 6) |  #params 576 | approx 2.532e-05  | approx.bound 3.612e-05
# 1  | (R1,R2) (10, 6) |  #params 576 | approx 2.532e-05  | approx.bound 3.612e-05
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 415.85950243254774 | Predefined Bound 415.8806400000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 33
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [31, 2]
# 0  | (R1,R2) (31, 2) |  #params 17457 | approx 0.02303  | approx.bound 0.02326
# 1  | (R1,R2) (31, 2) |  #params 17457 | approx 0.02303  | approx.bound 0.02326
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [33, 4]
# 0  | (R1,R2) (33, 4) |  #params 4669 | approx 0.000217  | approx.bound 0.0002376
# 1  | (R1,R2) (33, 4) |  #params 4669 | approx 0.000217  | approx.bound 0.0002376
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [16, 8]
# 0  | (R1,R2) (16, 8) |  #params 1904 | approx -6.978e-16  | approx.bound 2.055e-05
# 1  | (R1,R2) (16, 8) |  #params 1904 | approx -4.187e-16  | approx.bound 2.055e-05
# Approximation Error [310.16084007 310.16084007] | Predefined Bound 310.42872000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 34
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [21, 2]
# 0  | (R1,R2) (21, 2) |  #params 8047 | approx 0.04025  | approx.bound 0.04159
# 1  | (R1,R2) (21, 2) |  #params 8047 | approx 0.04025  | approx.bound 0.04159
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [18, 4]
# 0  | (R1,R2) (18, 4) |  #params 2014 | approx 0.001277  | approx.bound 0.001394
# 1  | (R1,R2) (18, 4) |  #params 2014 | approx 0.001277  | approx.bound 0.001394
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 8]
# 0  | (R1,R2) (12, 8) |  #params 904 | approx 7.93e-05  | approx.bound 0.0001173
# 1  | (R1,R2) (12, 8) |  #params 904 | approx 7.93e-05  | approx.bound 0.0001173
# Approximation Error [176.91544127 176.91544127] | Predefined Bound 177.07032000000004
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 35
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [15, 1]
# 0  | (R1,R2) (12, 1) |  #params 15926 | approx 0.02324  | approx.bound 0.02362
# 1  | (R1,R2) (12, 1) |  #params 15926 | approx 0.02324  | approx.bound 0.02362
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 1]
# 0  | (R1,R2) (8, 1) |  #params 354 | approx 0.000295  | approx.bound 0.0003801
# 1  | (R1,R2) (8, 1) |  #params 354 | approx 0.000295  | approx.bound 0.0003801
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [4, 2]
# 0  | (R1,R2) (4, 2) |  #params 84 | approx -2.786e-16  | approx.bound 8.514e-05
# 1  | (R1,R2) (4, 2) |  #params 84 | approx 2.786e-16  | approx.bound 8.514e-05
# Approximation Error [629.49988234 629.49988234] | Predefined Bound 631.7236800000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 36
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 1639 | approx 0.003023  | approx.bound 0.005731
# 1  | (R1,R2) (1, 1) |  #params 1639 | approx 0.003023  | approx.bound 0.005731
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [1, 1]
# 0  | (R1,R2) (1, 1) |  #params 9 | approx 5.743e-07  | approx.bound 0.002716
# 1  | (R1,R2) (1, 1) |  #params 9 | approx 5.743e-07  | approx.bound 0.002716
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 210.16804568786756 | Predefined Bound 398.34648000000004
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 37
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [25, 1]
# 0  | (R1,R2) (24, 1) |  #params 13562 | approx 0.01673  | approx.bound 0.01678
# 1  | (R1,R2) (24, 1) |  #params 13562 | approx 0.01673  | approx.bound 0.01678
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [64, 2]
# 0  | (R1,R2) (64, 2) |  #params 15364 | approx 4.598e-05  | approx.bound 4.605e-05
# 1  | (R1,R2) (64, 2) |  #params 15364 | approx 4.598e-05  | approx.bound 4.605e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 4]
# 0  | (R1,R2) (24, 4) |  #params 5200 | approx 1.962e-16  | approx.bound 7.107e-08
# 1  | (R1,R2) (24, 4) |  #params 5200 | approx -5.886e-16  | approx.bound 7.107e-08
# Perform the 4-th Tucker-2 decomposition
# Approximation Error 316.35444223648665 | Predefined Bound 316.3557600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 38
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [42, 2]
# 0  | (R1,R2) (42, 2) |  #params 41626 | approx 0.02384  | approx.bound 0.0241
# 1  | (R1,R2) (42, 2) |  #params 41626 | approx 0.02384  | approx.bound 0.0241
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [109, 4]
# 0  | (R1,R2) (109, 4) |  #params 45142 | approx 0.0002462  | approx.bound 0.0002628
# 1  | (R1,R2) (109, 4) |  #params 45142 | approx 0.0002462  | approx.bound 0.0002628
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [94, 8]
# 0  | (R1,R2) (94, 8) |  #params 39826 | approx 1.379e-05  | approx.bound 1.659e-05
# 1  | (R1,R2) (94, 8) |  #params 39826 | approx 1.379e-05  | approx.bound 1.659e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [32, 16]
# 0  | (R1,R2) (32, 16) |  #params 10304 | approx -6.365e-16  | approx.bound 2.801e-06
# 1  | (R1,R2) (32, 16) |  #params 10304 | approx -4.774e-16  | approx.bound 2.801e-06
# Approximation Error [564.48653614 564.48653614] | Predefined Bound 564.5505600000001
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 39
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [12, 2]
# 0  | (R1,R2) (12, 2) |  #params 6256 | approx 0.03663  | approx.bound 0.03703
# 1  | (R1,R2) (12, 2) |  #params 6256 | approx 0.03663  | approx.bound 0.03703
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [29, 4]
# 0  | (R1,R2) (29, 4) |  #params 4772 | approx 0.0003442  | approx.bound 0.0004104
# 1  | (R1,R2) (29, 4) |  #params 4772 | approx 0.0003442  | approx.bound 0.0004104
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [40, 8]
# 0  | (R1,R2) (40, 8) |  #params 4944 | approx 6.091e-05  | approx.bound 6.622e-05
# 1  | (R1,R2) (40, 8) |  #params 4944 | approx 6.091e-05  | approx.bound 6.622e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [31, 16]
# 0  | (R1,R2) (31, 16) |  #params 3728 | approx 3.817e-06  | approx.bound 5.306e-06
# 1  | (R1,R2) (31, 16) |  #params 3728 | approx 3.817e-06  | approx.bound 5.306e-06
# Approximation Error [270.65767467 270.65767467] | Predefined Bound 270.66816000000006
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 40
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [24, 1]
# 0  | (R1,R2) (13, 1) |  #params 15043 | approx 0.01709  | approx.bound 0.0171
# 1  | (R1,R2) (13, 1) |  #params 15043 | approx 0.01709  | approx.bound 0.0171
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [8, 2]
# 0  | (R1,R2) (8, 2) |  #params 380 | approx 1.131e-16  | approx.bound 4.022e-06
# 1  | (R1,R2) (8, 2) |  #params 380 | approx 0  | approx.bound 4.022e-06
# Perform the 3-th Tucker-2 decomposition
# Approximation Error 279.7409840430446 | Predefined Bound 279.80568000000005
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Decomposing for segment 41
# Perform the 1-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [11, 1]
# 0  | (R1,R2) (10, 1) |  #params 4062 | approx 0.01394  | approx.bound 0.01399
# 1  | (R1,R2) (10, 1) |  #params 4062 | approx 0.01394  | approx.bound 0.01399
# Perform the 2-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [18, 2]
# 0  | (R1,R2) (18, 2) |  #params 2668 | approx 3.095e-05  | approx.bound 4.756e-05
# 1  | (R1,R2) (18, 2) |  #params 2668 | approx 3.095e-05  | approx.bound 4.756e-05
# Perform the 3-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [26, 4]
# 0  | (R1,R2) (26, 4) |  #params 2616 | approx 1.594e-05  | approx.bound 1.662e-05
# 1  | (R1,R2) (26, 4) |  #params 2616 | approx 1.594e-05  | approx.bound 1.662e-05
# Perform the 4-th Tucker-2 decomposition
#
# Tucker-2 for denoising:
#
# Ranks [30, 8]
# 0  | (R1,R2) (30, 8) |  #params 2584 | approx 5.063e-07  | approx.bound 6.792e-07
# 1  | (R1,R2) (30, 8) |  #params 2584 | approx 5.063e-07  | approx.bound 6.792e-07
# Perform the 5-th Tucker-2 decomposition
# Approximation Error 395.1311849617414 | Predefined Bound 395.1360000000001
# --------------------------------------------------------------------
# TT uses 477925 parameters, compression ratio = 0.1645

# %%
np.prod(image.shape)
# Out:
# np.int64(187500)

# %%
reshape_for_tt
# Out:
# True

# %%
print(len(denoised_patches))
# print(denoised_patches[0][0])
# Out:
# 41

# %%
# 5. Reconstruct image
# Averaging
reconstructed = reconstruct_image_from_patches(
    denoised_patches, segments, noisy.shape, patch_size=patch_size
)
# # Using Marginal Median (High (resistant) to outliers), sharpens edge)
# recon_med = reconstruct_image_from_patches_median(
#     denoised_patches, segments, noisy.shape, patch_size=patch_size
# )  # Resists outlier

# %%
reconstructed_image = np.clip(reconstructed, 0, 1)
# reconstructed_image_med = np.clip(recon_med, 0, 1)

# %%
print(reconstructed_image.shape)
plt.imshow(reconstructed_image)
# Out:
# (250, 250, 3)

# %%
# print(reconstructed_image_med.shape)
# plt.imshow(reconstructed_image_med)

# %%
# 6. Compute metrics
psnr, ssim = compute_quality_metrics(
    original=image, 
    reconstructed=reconstructed_image
)
print(f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}")

# psnr, ssim = compute_quality_metrics(
#     original=image, 
#     reconstructed=reconstructed_image_med
# )
# print(f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}")
# Out:
# PSNR: 22.56, SSIM: 0.8730
